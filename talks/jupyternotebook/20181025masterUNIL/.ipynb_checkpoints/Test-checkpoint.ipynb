# %%
from collatex import *

collation = Collation()
collation.add_plain_witness("A", "The quick brown fox jumps over the dog.")
collation.add_plain_witness("B", "The brown fox jumps over the lazy dog.")

alignment_table = collate(collation)

# %%
print(alignment_table)
# Out:
# +---+-----+-------+--------------------------+------+------+
# | A | The | quick | brown fox jumps over the | -    | dog. |
# | B | The | -     | brown fox jumps over the | lazy | dog. |
# +---+-----+-------+--------------------------+------+------+

# %%
alignment_table = collate(collation, layout='vertical', output='html')
# Out:
# <table>
#     <tr>
#         <th>1940</th>
#         <th>1972</th>
#         <th>1933</th>
#     </tr>
#     <tr>
#         <td>-</td>
#         <td>-</td>
#         <td>29 juillet 33</td>
#     </tr>
#     <tr>
#         <td>(</td>
#         <td>(</td>
#         <td>(</td>
#     </tr>
#     <tr>
#         <td>Un tout</td>
#         <td>Un tout</td>
#         <td>un</td>
#     </tr>
#     <tr>
#         <td>petit écureuil brun<br>à poitrail blanc<br>bondit dans les<br>branches</td>
#         <td>petit écureuil brun<br>à poitrail blanc<br>bondit dans les<br>branches</td>
#         <td>petit écureuil brun<br>à poitrail blanc<br>bondit dans les<br>branches</td>
#     </tr>
#     <tr>
#         <td>-</td>
#         <td>-</td>
#         <td>du sapin</td>
#     </tr>
#     <tr>
#         <td>au-dessus de ma<br>tête ; sa queue bat<br>comme celle d’un<br>chat en colère.) Au<br>centre de moi-même</td>
#         <td>au-dessus de ma<br>tête ; sa queue bat<br>comme celle d’un<br>chat en colère.) Au<br>centre de moi-même</td>
#         <td>au-dessus de ma<br>tête; sa queue bat<br>comme celle d’un<br>chat en colère.) Au<br>centre de moi-même</td>
#     </tr>
#     <tr>
#         <td>,</td>
#         <td>-</td>
#         <td>,</td>
#     </tr>
#     <tr>
#         <td>il y avait le<br>moissonneur et la<br>moisson : cet<br>instant de l’année,</td>
#         <td>il y avait le<br>moissonneur et la<br>moisson : cet<br>instant de l’année,</td>
#         <td>il y avait le<br>moissonneur et la<br>moisson: cet instant<br>de l’année,</td>
#     </tr>
#     <tr>
#         <td>cet instant</td>
#         <td>ces instants</td>
#         <td>cet instant</td>
#     </tr>
#     <tr>
#         <td>de la vie d’un<br>homme, toute ma vie<br>s’appuyait sur eux,<br>s’enroulait<br>secrètement autour<br>d’eux. Cette passion<br>n’est pas quelque<br>chose d’extérieur<br>qui</td>
#         <td>de la vie d’un<br>homme, toute ma vie<br>s’appuyait sur eux,<br>s’enroulait<br>secrètement autour<br>d’eux. Cette passion<br>n’est pas quelque<br>chose d’extérieur<br>qui</td>
#         <td>de la vie d’un<br>homme, toute ma vie<br>s’appuyait sur eux,<br>s’enroulait<br>secrètement autour<br>d’eux. Cette passion<br>n’est pas quelque<br>chose d’extérieur<br>qui</td>
#     </tr>
#     <tr>
#         <td>se serait imposé</td>
#         <td>se serait imposé</td>
#         <td>s’est</td>
#     </tr>
#     <tr>
#         <td>-</td>
#         <td>,</td>
#         <td>-</td>
#     </tr>
#     <tr>
#         <td>peu à peu</td>
#         <td>peu à peu</td>
#         <td>peu à peu</td>
#     </tr>
#     <tr>
#         <td>,</td>
#         <td>,</td>
#         <td>imposé</td>
#     </tr>
#     <tr>
#         <td>à force d’insistance</td>
#         <td>à force d’insistance</td>
#         <td>à force d’insistance</td>
#     </tr>
#     <tr>
#         <td>,</td>
#         <td>,</td>
#         <td>-</td>
#     </tr>
#     <tr>
#         <td>à mon attente, c’est<br>une</td>
#         <td>à mon attente, c’est<br>une</td>
#         <td>à mon attente, c’est<br>une</td>
#     </tr>
#     <tr>
#         <td>&lt;i&gt;</td>
#         <td>&lt;i&gt;</td>
#         <td>-</td>
#     </tr>
#     <tr>
#         <td>correspondance</td>
#         <td>correspondance</td>
#         <td>correspondance</td>
#     </tr>
#     <tr>
#         <td>&lt;/i&gt;</td>
#         <td>&lt;/i&gt;</td>
#         <td>-</td>
#     </tr>
#     <tr>
#         <td>immédiate</td>
#         <td>immédiate</td>
#         <td>immédiate</td>
#     </tr>
#     <tr>
#         <td>-</td>
#         <td>-</td>
#         <td>, totale, mais non<br>immédiatement perçue<br>dans sa totalité.<br>Cette année-ci<br>seulement, je puis<br>m’en rendre compte,<br>en sentant chaque<br>jour croître<br>l’obsession<br>bienheureuse du<br>corps sombre</td>
#     </tr>
#     <tr>
#         <td>et</td>
#         <td>et</td>
#         <td>et</td>
#     </tr>
#     <tr>
#         <td>totale…</td>
#         <td>totale…</td>
#         <td>lisse parmi les épis<br>secs.</td>
#     </tr>
#     <tr>
#         <td>Voici quinze jours<br>que les blés ont<br>commencé à mûrir</td>
#         <td>Voici quinze jours<br>que les blés ont<br>commencé à mûrir </td>
#         <td>Voici quinze jours<br>que les blés ont<br>commencé à mûrir</td>
#     </tr>
#     <tr>
#         <td>. Cette</td>
#         <td>; cette</td>
#         <td>; cette</td>
#     </tr>
#     <tr>
#         <td>invasion d’or</td>
#         <td>invasion d’or</td>
#         <td>invasion d’or</td>
#     </tr>
#     <tr>
#         <td>-</td>
#         <td>-</td>
#         <td>parmi le vert comme<br>une sève précieuse</td>
#     </tr>
#     <tr>
#         <td>qui soudain éclaire<br>et découpe jusqu’à<br>l’horizon parmi le<br>vert des herbes<br>fraîches ou la brume<br>d’été toute bleue<br>les longs rectangles<br>jaunissants ou<br>fauves, m’atteint à<br>chaque</td>
#         <td>qui soudain éclaire<br>et découpe jusqu’à<br>l’horizon parmi le<br>vert des herbes<br>fraîches ou la brume<br>d’été toute bleue<br>les longs rectangles<br>jaunissants ou<br>fauves, m’atteint à<br>chaque</td>
#         <td>qui soudain éclaire<br>et découpe jusqu’à<br>l’horizon parmi le<br>vert des herbes<br>fraîches ou la brume<br>d’été toute bleue<br>les longs rectangles<br>jaunissants ou<br>fauves, m’atteint à<br>chaque</td>
#     </tr>
#     <tr>
#         <td>seconde</td>
#         <td>seconde</td>
#         <td>minute</td>
#     </tr>
#     <tr>
#         <td>et j’essaie en vain<br>de cerner ces<br>instants dont la<br>fuyante beauté<br>masque</td>
#         <td>et j’essaie en vain<br>de cerner ces<br>instants dont la<br>fuyante beauté<br>masque</td>
#         <td>et j’essaie en vain<br>de cerner ces<br>instants dont la<br>fuyante beauté<br>masque</td>
#     </tr>
#     <tr>
#         <td>,</td>
#         <td>,</td>
#         <td>–</td>
#     </tr>
#     <tr>
#         <td>mais annonce le<br>retombement de<br>l’année. Mon élan<br>vers l’épi dont le<br>grain éclate en lait<br>sucré sous la dent,<br>vers l’homme aux<br>cheveux brûlés, à</td>
#         <td>mais annonce le<br>retombement de<br>l’année. Mon élan<br>vers l’épi dont le<br>grain éclate en lait<br>sucré sous la dent,<br>vers l’homme aux<br>cheveux brûlés, à</td>
#         <td>mais annonce le<br>retombement de<br>l’année. Mon élan<br>vers l’épi dont le<br>grain éclate en lait<br>sucré sous la dent,<br>vers l’homme aux<br>cheveux brûlés, à</td>
#     </tr>
#     <tr>
#         <td>l’épaule</td>
#         <td>l’épaule</td>
#         <td>la peau</td>
#     </tr>
#     <tr>
#         <td>nue</td>
#         <td>-</td>
#         <td>nue</td>
#     </tr>
#     <tr>
#         <td>huilée de soleil</td>
#         <td>huilée de soleil</td>
#         <td>,</td>
#     </tr>
#     <tr>
#         <td>vient de si profond</td>
#         <td>vient de si profond</td>
#         <td>vient de si profond</td>
#     </tr>
#     <tr>
#         <td>en moi</td>
#         <td>-</td>
#         <td>en moi</td>
#     </tr>
#     <tr>
#         <td>qu’il me semble</td>
#         <td>qu’il me semble</td>
#         <td>qu’il me semble</td>
#     </tr>
#     <tr>
#         <td>souvent</td>
#         <td>souvent</td>
#         <td>parfois</td>
#     </tr>
#     <tr>
#         <td>que c’est</td>
#         <td>que c’est</td>
#         <td>que c’est</td>
#     </tr>
#     <tr>
#         <td>-</td>
#         <td>-</td>
#         <td>lui qui</td>
#     </tr>
#     <tr>
#         <td>&lt;</td>
#         <td>-</td>
#         <td>&lt;</td>
#     </tr>
#     <tr>
#         <td>i&gt;</td>
#         <td>-</td>
#         <td>u&gt;crée</td>
#     </tr>
#     <tr>
#         <td>lui</td>
#         <td>lui</td>
#         <td>-</td>
#     </tr>
#     <tr>
#         <td>&lt;/</td>
#         <td>-</td>
#         <td>&lt;/</td>
#     </tr>
#     <tr>
#         <td>i</td>
#         <td>-</td>
#         <td>u</td>
#     </tr>
#     <tr>
#         <td>&gt;</td>
#         <td>-</td>
#         <td>&gt;</td>
#     </tr>
#     <tr>
#         <td>qui crée</td>
#         <td>qui crée</td>
#         <td>-</td>
#     </tr>
#     <tr>
#         <td>le moissonneur et la<br>moisson.</td>
#         <td>le moissonneur et la<br>moisson.</td>
#         <td>le moissonneur et la<br>moisson.</td>
#     </tr>
#     <tr>
#         <td>-</td>
#         <td>-</td>
#         <td>2 août 33 La longue<br>pluie d’une nuit  7<br>août 33 Espèce de<br>crise de larmes une<br>fois assis à la<br>petite table dans<br>l’ombre verte et<br>rose de ma chambre.</td>
#     </tr>
#     <tr>
#         <td>-</td>
#         <t
